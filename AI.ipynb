# %% [markdown]
# 1. TSP

# %%
def nn_tsp(dist):
    n = len(dist)
    opt_cost = float('inf')
    opt_tour = []

    for start in range(n):
        unvisited = set(range(n))
        curr_city = start
        tour = [curr_city]
        total_dist = 0
        unvisited.remove(start)

        while unvisited:
            nearest_city = min(unvisited, key=lambda city:dist[curr_city][city])
            total_dist += dist[curr_city][nearest_city]
            tour.append(nearest_city)
            unvisited.remove(nearest_city)
            curr_city = nearest_city

            total_dist += dist[curr_city][start]
            tour.append(start)

            if total_dist < opt_cost:
                opt_cost = total_dist
                opt_tour = tour

            print(f"Path starting from city {start}: {tour}, Cost: {total_dist}")
        print("\nOptimal Tour:", opt_tour)
        print("Optimal Cost:", opt_cost)


if __name__ == "__main__":
    num_cities = int(input("Enter the number of cities: "))
    print("Enter the distance matrix:")

    distances = []
    for _ in range(num_cities):
        row = list(map(int, input().split()))
        distances.append(row)
    nn_tsp(distances)
# Out:
# Enter the number of cities: 4
# Enter the distance matrix:
# 0 20 25 15
# 20 0 30 35
# 25 30 0 40
# 15 35 40 0
# Path starting from city 0: [0, 3, 0], Cost:30
# Path starting from city 0: [0, 3, 0, 1, 0], Cost:85
# Path starting from city 0: [0, 3, 0, 1, 0, 2, 0], Cost:140
#
# Optimal Tour: [0, 3, 0, 1, 0, 2, 0]
# Optimal Cost: 30
# Path starting from city 1: [1, 0, 1], Cost:40
# Path starting from city 1: [1, 0, 1, 3, 1], Cost:90
# Path starting from city 1: [1, 0, 1, 3, 1, 2, 1], Cost:160
#
# Optimal Tour: [0, 3, 0, 1, 0, 2, 0]
# Optimal Cost: 30
# Path starting from city 2: [2, 0, 2], Cost:50
# Path starting from city 2: [2, 0, 2, 3, 2], Cost:105
# Path starting from city 2: [2, 0, 2, 3, 2, 1, 2], Cost:170
#
# Optimal Tour: [0, 3, 0, 1, 0, 2, 0]
# Optimal Cost: 30
# Path starting from city 3: [3, 0, 3], Cost:30
# Path starting from city 3: [3, 0, 3, 1, 3], Cost:85
# Path starting from city 3: [3, 0, 3, 1, 3, 2, 3], Cost:155
#
# Optimal Tour: [0, 3, 0, 1, 0, 2, 0]
# Optimal Cost: 30

# %% [markdown]
# 2. N-Queens

# %%
def isSafe(mat, r, c):
# Function to check if two queens threaten each other or not
    for i in range(r):
        if mat[i][c] == 'Q':
            return False
            # return false if two queens share the same column

    # return false if two queens share the same \ diagonal
    i, j = r, c
    while i >= 0 and j >= 0:
        if mat[i][j] == 'Q':
            return False
        i -= 1
        j -= 1

    # return false if two queens share the same / diagonal
    i, j = r, c
    while i >= 0 and j < len(mat):
        if mat[i][j] == 'Q':
            return False
        i -= 1
        j += 1

    return True

def printSolution(mat):
    for r in mat:
        print("".join(r))
    print()

def nQueen(mat, r):
    # if N queens are placed successfully, print the solution
    if r == len(mat):
        printSolution(mat)
        return

    # place queen at every square in the current row `r`
    # and recur for each valid movement
    for i in range(len(mat)):
        # if no two queens threaten each other
        if isSafe(mat, r, i):
            # place queen on the current square
            mat[r][i] = 'Q'
            # recur for the next row
            nQueen(mat, r + 1)
            # backtrack and remove the queen from the current square
            mat[r][i] = '-'

if __name__ == '__main__':

    N = 4

    mat = [['-' for x in range(N)] for y in range(N)]
    nQueen(mat, 0)
# Out:
# -Q--
# ---Q
# Q---
# --Q-
#
# --Q-
# Q---
# ---Q
# -Q--

# %% [markdown]
# 3. Water-Jug

# %%
def pour(jug1, jug2, max1, max2, fill):
    print("%d\t%d" % (jug1, jug2))
    if jug2 == fill:
        return
    elif jug2 == max2:
        pour(0, jug1, max1, max2, fill)
    elif jug1 != 0 and jug2 == 0:
        pour(0, jug1, max1, max2, fill)
    elif jug1 == fill:
        pour(jug1, 0, max1, max2, fill)
    elif jug1 < max1:
        pour(max1, jug2, max1, max2, fill)
    elif jug1 < (max2 - jug2):
        pour(0, (jug1 + jug2), max1, max2, fill)
    else:
        pour(jug1 - (max2 - jug2), (max2 - jug2) + jug2, max1, max2, fill)

# Ask user for input

max1 = int(input("Enter the capacity of Jug 1: "))
max2 = int(input("Enter the capacity of Jug 2: "))
fill = int(input("Enter the target volume to measure: "))
print("JUG1\tJUG2")

# Call the pour function with initial state
pour(0, 0, max1, max2, fill)
# Out:
# Enter the capacity of Jug 1: 3
# Enter the capacity of Jug 2: 4
# Enter the target volume to measure: 2
# JUG1	JUG2
# 0	0
# 3	0
# 0	3
# 3	3
# 2	4
# 0	2

# %% [markdown]
# 4. NLTK

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')

def tokenize_text(text):
    tokens = word_tokenize(text.lower()) # Tokenize the text
    return tokens

def count_word_frequency(tokens):
    word_freq = Counter(tokens) # Count the frequency of each word
    return word_freq

def remove_stop_words(tokens):
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if
word not in stop_words] # Remove stop words
    return filtered_tokens

def pos_tagging(tokens):
    tagged_tokens = pos_tag(tokens) # Perform POS tagging
    return tagged_tokens
# Take input from the user
text = input("Enter a sentence: ")
# Tokenization
tokens = tokenize_text(text)
# Word frequency count
word_freq = count_word_frequency(tokens)
# Removing stop words
filtered_tokens = remove_stop_words(tokens)
# POS tagging
tagged_tokens = pos_tagging(filtered_tokens)
print("Tokens:", tokens)
print("Word Frequency:", word_freq)
print("Filtered Tokens (after stop words removal):",filtered_tokens)
print("POS Tagged Tokens:", tagged_tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Enter a sentence: Hello, i am from BVCOEW Pune .
# Tokens: ['hello', ',', 'i', 'am', 'from', 'bvcoew', 'pune', '.']
# Word Frequency: Counter({'hello': 1, ',': 1, 'i': 1, 'am': 1, 'from': 1, 'bvcoew': 1, 'pune': 1, '.': 1})
# Filtered Tokens (after stop words removal): ['hello', ',', 'bvcoew', 'pune', '.']
# POS Tagged Tokens: [('hello', 'NN'), (',', ','), ('bvcoew', 'NN'), ('pune', 'NN'), ('.', '.')]
